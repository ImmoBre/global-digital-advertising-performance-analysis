# %% [markdown]
# # Global Digital Advertising Performance Analysis
#
# # 03 - Exploratory Data Analysis
#
# ## Objective
#
# The purpose of this notebook is to explore campaign performance across platforms, industries, campaign types, and countries. The analysis aims to identify trends, patterns, and business opportunities through descriptive statistics and data visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df = pd.read_csv("../data/global_ads_performance_dataset.csv")

df.head()
# Out:
#          date    platform campaign_type    industry  country  impressions  \
# 0  2024-01-21  Google Ads        Search     Fintech      UAE        59886
# 1  2024-01-22  TikTok Ads        Search      EdTech       UK       135608
# 2  2024-06-15  TikTok Ads         Video  Healthcare      USA        92313
# 3  2024-01-02  TikTok Ads      Shopping        SaaS  Germany        83953
# 4  2024-02-22  TikTok Ads        Search  Healthcare       UK        91807
#
#    clicks  CTR  CPC  ad_spend  conversions   CPA   revenue  ROAS
# 0    2113 0.04 1.26  2,662.38          159 16.74  4,803.43  1.80
# 1    5220 0.04 1.18  6,159.60          411 14.99 64,126.68 10.41
# 2    5991 0.06 0.85  5,092.35          267 19.07 10,489.07  2.06
# 3    5935 0.07 1.32  7,834.20          296 26.47 50,505.07  6.45
# 4    4489 0.05 1.93  8,663.77          107 80.97  3,369.53  0.39

# %% [markdown]
# ## Business Question 1
#
# ### Which advertising platform generates the highest total revenue?

# %%
revenue_by_platform = (
    df.groupby("platform")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

revenue_by_platform
# Out:
# platform
# Google Ads   22,033,744.95
# TikTok Ads   20,223,540.07
# Meta Ads     11,926,045.79
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    revenue_by_platform.index,
    revenue_by_platform.values
)

plt.title("Total Revenue by Platform")
plt.xlabel("Platform")
plt.ylabel("Revenue")

plt.show()

# %% [markdown]
# ### Insight
#
# This visualization compares the total revenue generated by each advertising platform. The results help identify which platform contributes the most to overall business performance and may guide future budget allocation decisions.

# %% [markdown]
# ## Business Question 2
#
# ### Which platform has the highest advertising spend?

# %%
spend = (
    df.groupby("platform")["ad_spend"]
    .sum()
    .sort_values(ascending=False)
)

spend
# Out:
# platform
# Google Ads   6,349,268.91
# TikTok Ads   2,653,418.51
# Meta Ads     2,106,061.67
# Name: ad_spend, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    spend.index,
    spend.values
)

plt.title("Total Advertising Spend by Platform")
plt.xlabel("Platform")
plt.ylabel("Advertising Spend")

plt.show()

# %% [markdown]
# ## Business Question 3
#
# ### Which platform delivers the highest Return on Ad Spend (ROAS)?

# %%
roas = (
    df.groupby("platform")
    .agg(
        total_revenue=("revenue", "sum"),
        total_ad_spend=("ad_spend", "sum")
    )
    .assign(
        ROAS=lambda data: (
            data["total_revenue"] /
            data["total_ad_spend"]
        )
    )["ROAS"]
    .sort_values(ascending=False)
)

roas
# Out:
# platform
# TikTok Ads   7.62
# Meta Ads     5.66
# Google Ads   3.47
# Name: ROAS, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    roas.index,
    roas.values
)

plt.title("ROAS by Platform")
plt.xlabel("Platform")
plt.ylabel("ROAS")

plt.show()

# %% [markdown]
# ## Campaign Type Analysis
#
# This section evaluates the performance of different campaign types to identify which strategies generate the strongest business outcomes.

# %% [markdown]
# ## Business Question 4
#
# ### Which campaign type generates the highest total revenue?

# %%
campaign_revenue = (
    df.groupby("campaign_type")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

campaign_revenue
# Out:
# campaign_type
# Search     15,218,470.85
# Video      13,341,261.19
# Shopping   12,824,695.60
# Display    12,798,903.17
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    campaign_revenue.index,
    campaign_revenue.values
)

plt.title("Total Revenue by Campaign Type")
plt.xlabel("Campaign Type")
plt.ylabel("Revenue")

plt.show()

# %% [markdown]
# ### Insight
#
# Comparing revenue across campaign types helps identify which marketing strategy contributes the most to overall business performance.

# %% [markdown]
# ## Business Question 5
#
# ### Which campaign type has the highest average ROAS?

# %%
campaign_roas = (
    df.groupby("campaign_type")
    .agg(
        total_revenue=("revenue", "sum"),
        total_ad_spend=("ad_spend", "sum")
    )
    .assign(
        ROAS=lambda data: (
            data["total_revenue"] /
            data["total_ad_spend"]
        )
    )["ROAS"]
    .sort_values(ascending=False)
)

campaign_roas
# Out:
# campaign_type
# Search     5.31
# Display    4.84
# Video      4.77
# Shopping   4.58
# Name: ROAS, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    campaign_roas.index,
    campaign_roas.values
)

plt.title("ROAS by Campaign Type")
plt.xlabel("Campaign Type")
plt.ylabel("ROAS")

plt.show()

# %% [markdown]
# ## Business Question 6
#
# ### Which campaign type receives the highest advertising spend?

# %%
campaign_spend = (
    df.groupby("campaign_type")["ad_spend"]
    .sum()
    .sort_values(ascending=False)
)

campaign_spend
# Out:
# campaign_type
# Search     2,868,006.85
# Shopping   2,799,548.64
# Video      2,796,458.48
# Display    2,644,735.12
# Name: ad_spend, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(
    campaign_spend.index,
    campaign_spend.values
)

plt.title("Advertising Spend by Campaign Type")
plt.xlabel("Campaign Type")
plt.ylabel("Ad Spend")

plt.show()

# %% [markdown]
# ## Industry Analysis
#
# This section compares advertising performance across industries to identify which sectors generate the strongest results.

# %% [markdown]
# ## Business Question 7
#
# ### Which industry generates the highest total revenue?

# %%
industry_revenue = (
    df.groupby("industry")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

industry_revenue
# Out:
# industry
# SaaS         11,891,991.42
# EdTech       11,549,934.43
# Healthcare   10,930,814.04
# Fintech      10,173,311.23
# E-commerce    9,637,279.69
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(9,5))

plt.bar(
    industry_revenue.index,
    industry_revenue.values,
    color="steelblue",
    edgecolor="black"
)

plt.title("Total Revenue by Industry", fontsize=14, weight="bold")
plt.xlabel("Industry")
plt.ylabel("Revenue")
plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# ## Business Question 8
#
# ### Which industry delivers the highest average ROAS?

# %%
industry_roas = (
    df.groupby("industry")
    .agg(
        total_revenue=("revenue", "sum"),
        total_ad_spend=("ad_spend", "sum")
    )
    .assign(
        ROAS=lambda data: (
            data["total_revenue"] /
            data["total_ad_spend"]
        )
    )["ROAS"]
    .sort_values(ascending=False)
)

industry_roas
# Out:
# industry
# SaaS         5.04
# EdTech       5.03
# E-commerce   5.01
# Healthcare   4.84
# Fintech      4.48
# Name: ROAS, dtype: float64

# %%
plt.figure(figsize=(9,5))

plt.bar(
    industry_roas.index,
    industry_roas.values,
    color="steelblue",
    edgecolor="black"
)

plt.title("ROAS by Industry", fontsize=14, weight="bold")
plt.xlabel("Industry")
plt.ylabel("ROAS")
plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The SaaS industry generated the highest total revenue, indicating strong overall campaign performance. However, EdTech achieved the highest average ROAS, suggesting that advertising investments in this sector are the most efficient.
#
# This demonstrates that maximizing revenue and maximizing advertising efficiency are not always the same objective. Decision-makers should consider both metrics when allocating marketing budgets.

# %% [markdown]
# ## Country Analysis
#
# This section evaluates advertising performance across different countries to identify the markets that generate the highest revenue and advertising efficiency.

# %% [markdown]
# ## Business Question 9
#
# ### Which country generates the highest total revenue?

# %%
country_revenue = (
    df.groupby("country")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

country_revenue
# Out:
# country
# UAE         7,939,594.41
# Australia   7,921,847.84
# India       7,909,606.26
# Canada      7,867,323.12
# Germany     7,694,838.61
# UK          7,659,544.29
# USA         7,190,576.28
# Name: revenue, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.bar(
    country_revenue.index,
    country_revenue.values,
    color="steelblue",
    edgecolor="black"
)

plt.title(
    "Total Revenue by Country",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Country")
plt.ylabel("Revenue")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# ## Business Question 10
#
# ### Which country achieves the highest average ROAS?

# %%
country_roas = (
    df.groupby("country")
    .agg(
        total_revenue=("revenue", "sum"),
        total_ad_spend=("ad_spend", "sum")
    )
    .assign(
        ROAS=lambda data: (
            data["total_revenue"] /
            data["total_ad_spend"]
        )
    )["ROAS"]
    .sort_values(ascending=False)
)

country_roas
# Out:
# country
# India       5.50
# Australia   4.99
# Germany     4.96
# UK          4.95
# UAE         4.92
# Canada      4.79
# USA         4.16
# Name: ROAS, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.bar(
    country_roas.index,
    country_roas.values,
    color="steelblue",
    edgecolor="black"
)

plt.title(
    "ROAS by Country",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Country")
plt.ylabel("ROAS")

plt.grid(axis="y", alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The UAE generated the highest total revenue, while India achieved the highest aggregate ROAS at approximately 5.50. The USA recorded the lowest aggregate ROAS at approximately 4.16. These results demonstrate that the largest market by revenue is not necessarily the most efficient market by return on advertising spend.

# %% [markdown]
# # Time-Series Analysis
#
# This section examines how campaign performance changes over time to identify trends and seasonal patterns.
#
# ## Business Question 11
#
# ### How does total revenue evolve over time?

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
monthly_revenue = (
    df.groupby(df["date"].dt.to_period("M"))["revenue"]
    .sum()
)

monthly_revenue
# Out:
# date
# 2024-01   4,691,994.47
# 2024-02   4,749,203.46
# 2024-03   4,407,519.38
# 2024-04   5,143,463.57
# 2024-05   3,768,913.36
# 2024-06   4,362,176.31
# 2024-07   3,695,093.97
# 2024-08   4,301,659.26
# 2024-09   4,749,430.27
# 2024-10   4,670,520.68
# 2024-11   4,484,002.75
# 2024-12   5,159,353.33
# Freq: M, Name: revenue, dtype: float64

# %%
plt.figure(figsize=(12,5))

plt.plot(
    monthly_revenue.index.astype(str),
    monthly_revenue.values,
    marker="o",
    linewidth=2
)

plt.title(
    "Monthly Revenue Trend",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Month")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# Monthly revenue fluctuated throughout 2024 rather than following a consistent upward trend. The highest revenue was recorded in **December (approximately 5.16 million)**, while **July generated the lowest revenue (approximately 3.70 million)**.
#
# The strong performance in April and December may indicate seasonal effects or more effective campaign execution during these periods. In contrast, the decline observed in May and July suggests opportunities for campaign optimization or budget reallocation.

# %% [markdown]
# ## Business Question 12
#
# ### How does advertising spend evolve over time?

# %%
monthly_spend = (
    df.groupby(df["date"].dt.to_period("M"))["ad_spend"]
    .sum()
)

monthly_spend
# Out:
# date
# 2024-01     901,735.06
# 2024-02     988,588.36
# 2024-03     837,915.28
# 2024-04   1,032,895.90
# 2024-05     904,564.26
# 2024-06     966,952.76
# 2024-07     797,918.14
# 2024-08     819,622.05
# 2024-09   1,010,523.04
# 2024-10     868,099.26
# 2024-11     882,564.99
# 2024-12   1,097,369.99
# Freq: M, Name: ad_spend, dtype: float64

# %%
plt.figure(figsize=(12,5))

plt.plot(
    monthly_spend.index.astype(str),
    monthly_spend.values,
    marker="o",
    linewidth=2
)

plt.title(
    "Monthly Advertising Spend",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Month")
plt.ylabel("Advertising Spend")

plt.xticks(rotation=45)

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# Advertising expenditure varied across the year, with the highest investment occurring in **December (approximately 1.10 million)** and the lowest in **July (approximately 0.80 million)**.
#
# Interestingly, months with higher advertising spend generally correspond to higher revenue, suggesting a positive relationship between investment and business performance. However, additional analysis is required to determine whether increased spending consistently leads to proportional revenue growth.

# %% [markdown]
# # Relationship Analysis
#
# This section investigates the relationships between key marketing metrics to better understand campaign performance.
#
# ## Business Question 13
#
# ### Is there a relationship between advertising spend and revenue?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["ad_spend"],
    df["revenue"],
    alpha=0.6
)

plt.title(
    "Advertising Spend vs Revenue",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Advertising Spend")
plt.ylabel("Revenue")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The scatter plot indicates a generally positive relationship between advertising spend and revenue, suggesting that higher investment tends to generate higher returns.
#
# However, the relationship is not perfectly linear. Several campaigns with substantial advertising spend produced relatively modest revenue, while some lower-spend campaigns achieved strong results. This suggests that campaign effectiveness depends not only on budget size but also on targeting, platform selection, and campaign strategy.
#
# Marketing managers should therefore optimize spending efficiency rather than simply increasing budgets.

# %% [markdown]
# ## Business Question 14
#
# ### Is there a relationship between clicks and conversions?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df["clicks"],
    df["conversions"],
    alpha=0.6
)

plt.title(
    "Clicks vs Conversions",
    fontsize=14,
    weight="bold"
)

plt.xlabel("Clicks")
plt.ylabel("Conversions")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The analysis reveals a strong positive relationship between clicks and conversions. Campaigns that attract more user engagement generally produce a higher number of conversions.
#
# This finding highlights the importance of improving click generation through effective creatives and targeting strategies, as increased engagement is strongly associated with improved campaign outcomes.

# %% [markdown]
# ## Business Question 15
#
# ### Which variables are most strongly correlated?

# %%
correlation = df.select_dtypes(include="number").corr()

correlation
# Out:
#              impressions  clicks   CTR   CPC  ad_spend  conversions   CPA  \
# impressions         1.00    0.72  0.01  0.00      0.58         0.58 -0.01
# clicks              0.72    1.00  0.62 -0.03      0.73         0.82 -0.02
# CTR                 0.01    0.62  1.00 -0.05      0.40         0.51 -0.04
# CPC                 0.00   -0.03 -0.05  1.00      0.55        -0.05  0.59
# ad_spend            0.58    0.73  0.40  0.55      1.00         0.56  0.34
# conversions         0.58    0.82  0.51 -0.05      0.56         1.00 -0.32
# CPA                -0.01   -0.02 -0.04  0.59      0.34        -0.32  1.00
# revenue             0.48    0.68  0.41 -0.02      0.48         0.83 -0.26
# ROAS                0.03    0.07  0.07 -0.51     -0.26         0.28 -0.50
#
#              revenue  ROAS
# impressions     0.48  0.03
# clicks          0.68  0.07
# CTR             0.41  0.07
# CPC            -0.02 -0.51
# ad_spend        0.48 -0.26
# conversions     0.83  0.28
# CPA            -0.26 -0.50
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

plt.imshow(correlation, cmap="Blues", aspect="auto")

plt.colorbar()

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=90
)

plt.yticks(
    range(len(correlation.columns)),
    correlation.columns
)

plt.title(
    "Correlation Matrix",
    fontsize=14,
    weight="bold"
)

plt.show()

# %% [markdown]
# ### Business Insight
#
# The correlation matrix demonstrates strong positive relationships among several marketing metrics. In particular:
#
# - Clicks and conversions exhibit a high positive correlation.
# - Advertising spend shows a positive relationship with revenue.
# - Revenue and ROAS are positively associated.
# - CPA displays weaker or negative relationships with several performance metrics, indicating that lower acquisition costs may contribute to improved campaign efficiency.
#
# Overall, the analysis suggests that engagement metrics and investment levels are key drivers of campaign performance.
